# %% [markdown]
# #### 1. What is spaCy?
#
# spaCy is an open-source industrial-strength Natural Language Processing (NLP) library in Python.
# It is designed for speed, scalability, and production use.
#
# spaCy organizes its NLP tasks into a processing pipeline, which includes:
#
# - Tokenization
# - Part-of-Speech (POS) Tagging
# - Named Entity Recognition (NER)
# - Dependency Parsing
#
# When you load a model with spacy.load("en_core_web_sm"), you get an NLP object containing the model and pipeline components.
#
# #### 2. spaCy Processing Pipeline
#
# Here’s how spaCy processes text internally:
#
# - Text Input → The raw string is passed to the NLP object
# - Tokenizer → Splits text into words, punctuation, etc.
# - Tagger → Assigns POS tags like NOUN, VERB, ADJ
# - Parser → Builds dependency trees
# - NER → Detects named entities like people, places, or organizations
# - Doc Object → Final structured representation of the text
#
# 💡 The resulting object is called a Doc, which contains Tokens, Sentences, Entities, and linguistic annotations.
#
# #### 3. Example: Tokenization and POS Tagging

# %%
import spacy

# Load the English model
nlp = spacy.load("en_core_web_sm")

# Sample text
text = "This is an example sentence."

# Process the text
doc = nlp(text)

# Print tokens and their Part-of-Speech tags
print("Token  |  POS Tag")
print("-------------------")
for token in doc:
    print(f"{token.text:<10} {token.pos_}")
# Out:
# Token  |  POS Tag
# -------------------
# This       PRON
# is         AUX
# an         DET
# example    NOUN
# sentence   NOUN
# .          PUNCT

# %% [markdown]
# #### 4. Dependency Parsing
#
# Dependency parsing analyzes grammatical relationships between words.
#
# It helps in identifying subjects, verbs, and objects in sentences.

# %%
# Print dependency labels for each token
for token in doc:
    print(f"{token.text:<10} → {token.dep_:<10} (Head: {token.head.text})")
# Out:
# This       → nsubj      (Head: is)
# is         → ROOT       (Head: is)
# an         → det        (Head: sentence)
# example    → compound   (Head: sentence)
# sentence   → attr       (Head: is)
# .          → punct      (Head: is)

# %% [markdown]
# #### 5. Named Entity Recognition (NER)
#
# Named Entity Recognition identifies names of people, organizations, locations, etc.

# %%
text = "Online Store Incorporated is planning to open a new store in San Francisco. Cora Greene, the CEO, will attend the launch."

doc = nlp(text)

print("Named           Entities:")
print("-----------------------")
for ent in doc.ents:
    print(f"{ent.text:<25} → {ent.label_}")
# Out:
# Named           Entities:
# -----------------------
# San Francisco             → GPE
# Cora Greene               → PERSON

# %% [markdown]
# #### 6. Practical Example: Product Review Analysis

# %%
text = "Your products are excellent and the delivery was super fast!"
doc = nlp(text)

print("Tokens:")
print([token.text for token in doc])

print("\nPOS Tags:")
print([(token.text, token.pos_) for token in doc])

print("\nEntities:")
print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Tokens:
# ['Your', 'products', 'are', 'excellent', 'and', 'the', 'delivery', 'was', 'super', 'fast', '!']
#
# POS Tags:
# [('Your', 'PRON'), ('products', 'NOUN'), ('are', 'AUX'), ('excellent', 'ADJ'), ('and', 'CCONJ'), ('the', 'DET'), ('delivery', 'NOUN'), ('was', 'AUX'), ('super', 'ADV'), ('fast', 'ADJ'), ('!', 'PUNCT')]
#
# Entities:
# []

# %% [markdown]
# #### 7. Visualizing Dependencies
#
# You can visualize dependencies directly inside Jupyter:

# %%
from spacy import displacy

displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0d83e1ebe3984a749e46249bad3c2501-0" class="displacy" width="1800" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">products</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">excellent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">delivery</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">super</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">fast!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d83e1ebe3984a749e46249bad3c2501-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d83e1ebe3984a749e46249bad3c2501-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d83e1ebe3984a749e46249bad3c2501-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d83e1ebe3984a749e46249bad3c2501-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d83e1ebe3984a749e46249bad3c2501-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d83e1ebe3984a749e46249bad3c2501-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,266.5 L573.0,254.5 557.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d83e1ebe3984a749e46249bad3c2501-0-3" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d83e1ebe3984a749e46249bad3c2501-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,266.5 L753.0,254.5 737.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d83e1ebe3984a749e46249bad3c2501-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d83e1ebe3984a749e46249bad3c2501-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d83e1ebe3984a749e46249bad3c2501-0-5" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d83e1ebe3984a749e46249bad3c2501-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d83e1ebe3984a749e46249bad3c2501-0-6" stroke-width="2px" d="M420,264.5 C420,2.0 1275.0,2.0 1275.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d83e1ebe3984a749e46249bad3c2501-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1275.0,266.5 L1283.0,254.5 1267.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d83e1ebe3984a749e46249bad3c2501-0-7" stroke-width="2px" d="M1470,264.5 C1470,177.0 1615.0,177.0 1615.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d83e1ebe3984a749e46249bad3c2501-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1470,266.5 L1462,254.5 1478,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d83e1ebe3984a749e46249bad3c2501-0-8" stroke-width="2px" d="M1295,264.5 C1295,89.5 1620.0,89.5 1620.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d83e1ebe3984a749e46249bad3c2501-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1620.0,266.

# %% [markdown]
# #### 8. Key Takeaways
#
# - spaCy provides an efficient pipeline for language processing.
# - Each Doc object stores rich linguistic information — tokens, POS tags, entities, and dependencies.
# - NER and dependency parsing help structure unstructured text into usable data.
# - spaCy is ideal for real-world, production-level NLP applications.
